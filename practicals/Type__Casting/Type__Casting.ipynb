# %%
a="What_is_Type__Casting_in_Python?"
b=str(a)
#Converting String to List of Characters..
print("1. Converting String to List of Characters: ",b)

#Converting String to List..
x=list(a)
print("2. Converting String to List..\n",x)

#Converting String to Tuple..
tuplex=tuple(a)
print("3. Converting String to Tuple..\n",tuplex)

#Converting String to Set.
set1=set(a)
print("4. Converting String to Set..\n",set1) #Unordered Collection..


#Converting Tuple to List..
list_tuple=list(tuplex)
print("5. Converting Tuple to List..\n",list_tuple)

#Converting List to Tuple..
tuple_list=tuple(x)
print("6. Converting List to Tuple..\n",tuple_list)

#Converting Set to List..
list_set=list(set1)
print("7. Converting Set to List..\n",list_set) #Unordered Collection..

#Converting List to Set..
set_list=set(x)
print("8. Converting List to Set..\n",set_list) #Unordered Collection..

#Converting Set to Tuple..
tuple_set=tuple(set1)
print("9. Converting Set to Tuple..\n",tuple_set) #Unordered Collection..

#Converting Tuple to Set..
set_tuple=set(tuplex)
print("10. Converting Tuple to Set..\n",set_tuple) #Unordered Collection..

#Converting Dictionary from List of List..
lst1=[[1,2],[3,4],[5,6]]
#lst1=[[1,2,3],[3,4],[5,6]]
#dictionary update sequence element #0 has length 3; 2 is required
dict1=dict(lst1)
print("11. Converting Dictionary from List of List..\n",dict1)

#Converting Dictionary from List of Tuple..
lst2=[(7,8),(9,10)]
dict2=dict(lst2)
print("12. Converting Dictionary from List of Tuple..\n",dict2)

#Converting Dictionary from List of Set..
lst3=[{11,12},{13,14}]
dict3=dict(lst3)
print("13. Converting Dictionary from List of Set..\n",dict3)

#Converting Dictionary from Tuple of Tuple..
tuple4=((15,16),(17,18))
dict4=dict(tuple4)
print("14. Converting Dictionary from Tuple to Tuple..\n",dict4)

#Converting Dictionary from Tuple of List..
tuple5=([19,20],(21,22))
dict5=dict(tuple5)
print("15. Converting Dictionary from Tuple of List..\n",dict5)

#Converting Dictionary from Tuple of Set..
tuple6=({23,24},{25,26})
dict6=dict(tuple6)
print("16. Converting Dictionary from Tuple of Set..\n",dict6)

#Converting Dictionary from Set of Tuple..
set7={(27,28),(29,30)}
dict7=dict(set7)
print("17. Converting Dictionary fromSet of Tuple..\n",dict7)

#Converting Dictionary from Set of List..
set8={[31,32],[33,34]}
dict8=dict(set8)
print("18. Connverting Dictionary from Set of List..\n",dict8)
# unhashable type: 'list'

##It, will show Error because
##We can't make Dictionary from Set of List
##& Set of Set..

#Converting Dictionary from Set of Set..
set9={{35,36},{37,38}}
dict9=dict(set9)
print("19. Converting Dictionary from Set of Set..\n",dict9)
# unhashable type: 'list'
# Out:
# 1. Converting String to List of Characters:  What_is_Type__Casting_in_Python?
# 2. Converting String to List..
#  ['W', 'h', 'a', 't', '_', 'i', 's', '_', 'T', 'y', 'p', 'e', '_', '_', 'C', 'a', 's', 't', 'i', 'n', 'g', '_', 'i', 'n', '_', 'P', 'y', 't', 'h', 'o', 'n', '?']
# 3. Converting String to Tuple..
#  ('W', 'h', 'a', 't', '_', 'i', 's', '_', 'T', 'y', 'p', 'e', '_', '_', 'C', 'a', 's', 't', 'i', 'n', 'g', '_', 'i', 'n', '_', 'P', 'y', 't', 'h', 'o', 'n', '?')
# 4. Converting String to Set..
#  {'o', 't', 'p', 'i', 'n', 'P', 's', 'T', 'y', '_', 'W', 'C', 'g', '?', 'a', 'h', 'e'}
# 5. Converting Tuple to List..
#  ['W', 'h', 'a', 't', '_', 'i', 's', '_', 'T', 'y', 'p', 'e', '_', '_', 'C', 'a', 's', 't', 'i', 'n', 'g', '_', 'i', 'n', '_', 'P', 'y', 't', 'h', 'o', 'n', '?']
# 6. Converting List to Tuple..
#  ('W', 'h', 'a', 't', '_', 'i', 's', '_', 'T', 'y', 'p', 'e', '_', '_', 'C', 'a', 's', 't', 'i', 'n', 'g', '_', 'i', 'n', '_', 'P', 'y', 't', 'h', 'o', 'n', '?')
# ...
